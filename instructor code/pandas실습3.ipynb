# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.random.randn(5,4))
df.columns = ["A", "B", "C", "D"]
df
# Out:
#           A         B         C         D
# 0 -0.276777  0.003919  0.249703  0.407586
# 1 -0.057876  0.671420 -0.685983  0.804780
# 2 -0.057425  0.868426 -0.459067 -1.086346
# 3 -0.665913  0.905790  0.420357  0.046141
# 4 -0.208379 -1.785672 -0.561937 -0.003012

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.index = pd.date_range("20180214", periods=5)

# %%
df.index
# Out:
# DatetimeIndex(['2018-02-14', '2018-02-15', '2018-02-16', '2018-02-17',
#                '2018-02-18'],
#               dtype='datetime64[ns]', freq='D')

# %%
df
# Out:
#                    A         B         C         D
# 2018-02-14 -0.276777  0.003919  0.249703  0.407586
# 2018-02-15 -0.057876  0.671420 -0.685983  0.804780
# 2018-02-16 -0.057425  0.868426 -0.459067 -1.086346
# 2018-02-17 -0.665913  0.905790  0.420357  0.046141
# 2018-02-18 -0.208379 -1.785672 -0.561937 -0.003012

# %%
df["E"] = [10, np.nan, 9.9, 9.8, np.nan]
df
# Out:
#                    A         B         C         D     E
# 2018-02-14 -0.276777  0.003919  0.249703  0.407586  10.0
# 2018-02-15 -0.057876  0.671420 -0.685983  0.804780   NaN
# 2018-02-16 -0.057425  0.868426 -0.459067 -1.086346   9.9
# 2018-02-17 -0.665913  0.905790  0.420357  0.046141   9.8
# 2018-02-18 -0.208379 -1.785672 -0.561937 -0.003012   NaN

# %%
df.dropna(how="any")
#df.dropna(how="any", inplace=True)
# Out:
#                    A         B         C         D     E
# 2018-02-14 -0.276777  0.003919  0.249703  0.407586  10.0
# 2018-02-16 -0.057425  0.868426 -0.459067 -1.086346   9.9
# 2018-02-17 -0.665913  0.905790  0.420357  0.046141   9.8

# %%
df
# Out:
#                    A         B         C         D     E
# 2018-02-14 -0.276777  0.003919  0.249703  0.407586  10.0
# 2018-02-15 -0.057876  0.671420 -0.685983  0.804780   NaN
# 2018-02-16 -0.057425  0.868426 -0.459067 -1.086346   9.9
# 2018-02-17 -0.665913  0.905790  0.420357  0.046141   9.8
# 2018-02-18 -0.208379 -1.785672 -0.561937 -0.003012   NaN

# %%
df.dropna(how="all")
# Out:
#                    A         B         C         D     E
# 2018-02-14 -0.276777  0.003919  0.249703  0.407586  10.0
# 2018-02-15 -0.057876  0.671420 -0.685983  0.804780   NaN
# 2018-02-16 -0.057425  0.868426 -0.459067 -1.086346   9.9
# 2018-02-17 -0.665913  0.905790  0.420357  0.046141   9.8
# 2018-02-18 -0.208379 -1.785672 -0.561937 -0.003012   NaN

# %%
df.fillna(value=9.9)
# Out:
#                    A         B         C         D     E
# 2018-02-14 -0.276777  0.003919  0.249703  0.407586  10.0
# 2018-02-15 -0.057876  0.671420 -0.685983  0.804780   9.9
# 2018-02-16 -0.057425  0.868426 -0.459067 -1.086346   9.9
# 2018-02-17 -0.665913  0.905790  0.420357  0.046141   9.8
# 2018-02-18 -0.208379 -1.785672 -0.561937 -0.003012   9.9

# %%
df
# Out:
#                    A         B         C         D     E
# 2018-02-14 -0.276777  0.003919  0.249703  0.407586  10.0
# 2018-02-15 -0.057876  0.671420 -0.685983  0.804780   NaN
# 2018-02-16 -0.057425  0.868426 -0.459067 -1.086346   9.9
# 2018-02-17 -0.665913  0.905790  0.420357  0.046141   9.8
# 2018-02-18 -0.208379 -1.785672 -0.561937 -0.003012   NaN

# %%
df.fillna(value=9.9, inplace=True)

# %%
df
# Out:
#                    A         B         C         D     E
# 2018-02-14 -0.276777  0.003919  0.249703  0.407586  10.0
# 2018-02-15 -0.057876  0.671420 -0.685983  0.804780   9.9
# 2018-02-16 -0.057425  0.868426 -0.459067 -1.086346   9.9
# 2018-02-17 -0.665913  0.905790  0.420357  0.046141   9.8
# 2018-02-18 -0.208379 -1.785672 -0.561937 -0.003012   9.9

# %%
df.isnull()
# Out:
#                 A      B      C      D      E
# 2018-02-14  False  False  False  False  False
# 2018-02-15  False  False  False  False  False
# 2018-02-16  False  False  False  False  False
# 2018-02-17  False  False  False  False  False
# 2018-02-18  False  False  False  False  False

# %%
df
# Out:
#                    A         B         C         D     E
# 2018-02-14 -0.276777  0.003919  0.249703  0.407586  10.0
# 2018-02-15 -0.057876  0.671420 -0.685983  0.804780   9.9
# 2018-02-16 -0.057425  0.868426 -0.459067 -1.086346   9.9
# 2018-02-17 -0.665913  0.905790  0.420357  0.046141   9.8
# 2018-02-18 -0.208379 -1.785672 -0.561937 -0.003012   9.9

# %%
pd.to_datetime("20180214")
# Out:
# Timestamp('2018-02-14 00:00:00')

# %%
df.index
# Out:
# DatetimeIndex(['2018-02-14', '2018-02-15', '2018-02-16', '2018-02-17',
#                '2018-02-18'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.drop( pd.to_datetime("20180215"))
# Out:
#                    A         B         C         D     E
# 2018-02-14 -0.276777  0.003919  0.249703  0.407586  10.0
# 2018-02-16 -0.057425  0.868426 -0.459067 -1.086346   9.9
# 2018-02-17 -0.665913  0.905790  0.420357  0.046141   9.8
# 2018-02-18 -0.208379 -1.785672 -0.561937 -0.003012   9.9

# %%
df.drop( [pd.to_datetime("20180215"), pd.to_datetime("20180217")])
# Out:
#                    A         B         C         D     E
# 2018-02-14 -0.276777  0.003919  0.249703  0.407586  10.0
# 2018-02-16 -0.057425  0.868426 -0.459067 -1.086346   9.9
# 2018-02-18 -0.208379 -1.785672 -0.561937 -0.003012   9.9

# %%
#에러
#df.drop( [pd.to_datetime("20180215"): pd.to_datetime("20180217")])

# %%
df.drop("E", axis=1)
# Out:
#                    A         B         C         D
# 2018-02-14 -0.276777  0.003919  0.249703  0.407586
# 2018-02-15 -0.057876  0.671420 -0.685983  0.804780
# 2018-02-16 -0.057425  0.868426 -0.459067 -1.086346
# 2018-02-17 -0.665913  0.905790  0.420357  0.046141
# 2018-02-18 -0.208379 -1.785672 -0.561937 -0.003012

# %%
df
# Out:
#                    A         B         C         D     E
# 2018-02-14 -0.276777  0.003919  0.249703  0.407586  10.0
# 2018-02-15 -0.057876  0.671420 -0.685983  0.804780   9.9
# 2018-02-16 -0.057425  0.868426 -0.459067 -1.086346   9.9
# 2018-02-17 -0.665913  0.905790  0.420357  0.046141   9.8
# 2018-02-18 -0.208379 -1.785672 -0.561937 -0.003012   9.9

# %%
del df["E"]

# %%
df
# Out:
#                    A         B         C         D
# 2018-02-14 -0.276777  0.003919  0.249703  0.407586
# 2018-02-15 -0.057876  0.671420 -0.685983  0.804780
# 2018-02-16 -0.057425  0.868426 -0.459067 -1.086346
# 2018-02-17 -0.665913  0.905790  0.420357  0.046141
# 2018-02-18 -0.208379 -1.785672 -0.561937 -0.003012

# %%
df.drop(["B","D"], axis=1 )
# Out:
#                    A         C
# 2018-02-14 -0.276777  0.249703
# 2018-02-15 -0.057876 -0.685983
# 2018-02-16 -0.057425 -0.459067
# 2018-02-17 -0.665913  0.420357
# 2018-02-18 -0.208379 -0.561937

# %%
#df.drop("B":"D", axis=1 )
#df.drop(1:3, axis=1 )

# %%
# 에러는 아닌데 결과가 다름. 인덱스만 남는다
df.drop(df.iloc[1:3], axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [2018-02-14 00:00:00, 2018-02-15 00:00:00, 2018-02-16 00:00:00, 2018-02-17 00:00:00, 2018-02-18 00:00:00]

# %%
df
# Out:
#                    A         B         C         D
# 2018-02-14 -0.276777  0.003919  0.249703  0.407586
# 2018-02-15 -0.057876  0.671420 -0.685983  0.804780
# 2018-02-16 -0.057425  0.868426 -0.459067 -1.086346
# 2018-02-17 -0.665913  0.905790  0.420357  0.046141
# 2018-02-18 -0.208379 -1.785672 -0.561937 -0.003012

# %%
df.drop(df.index[2] )
# Out:
#                    A         B         C         D
# 2018-02-14 -0.276777  0.003919  0.249703  0.407586
# 2018-02-15 -0.057876  0.671420 -0.685983  0.804780
# 2018-02-17 -0.665913  0.905790  0.420357  0.046141
# 2018-02-18 -0.208379 -1.785672 -0.561937 -0.003012

# %%
df.drop(df.index[[2,4]] )
# Out:
#                    A         B         C         D
# 2018-02-14 -0.276777  0.003919  0.249703  0.407586
# 2018-02-15 -0.057876  0.671420 -0.685983  0.804780
# 2018-02-17 -0.665913  0.905790  0.420357  0.046141

# %%
#에러
df.drop(df.index[2:4] )
# Out:
#                    A         B         C         D
# 2018-02-14 -0.276777  0.003919  0.249703  0.407586
# 2018-02-15 -0.057876  0.671420 -0.685983  0.804780
# 2018-02-18 -0.208379 -1.785672 -0.561937 -0.003012

# %%
df
# Out:
#                    A         B         C         D
# 2018-02-14 -0.276777  0.003919  0.249703  0.407586
# 2018-02-15 -0.057876  0.671420 -0.685983  0.804780
# 2018-02-16 -0.057425  0.868426 -0.459067 -1.086346
# 2018-02-17 -0.665913  0.905790  0.420357  0.046141
# 2018-02-18 -0.208379 -1.785672 -0.561937 -0.003012
