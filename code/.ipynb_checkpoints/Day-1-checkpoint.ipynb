# %%
3+2
# Out:
# 5

# %%
print?

# %%
# %who
# Out:
# Interactive namespace is empty.

# %%
# %run 4-1-1.py
# Out:
# Input Score: 99
# Grade is A

# %%
# %run ../code/4-1-1.py
# Out:
# Input Score: 99
# Grade is A
